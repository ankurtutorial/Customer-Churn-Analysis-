# %%
import numpy as np 
import pandas as pd
import matplotlib as plt
import seaborn as sns
df = pd.read_csv("C:\\Users\\MANISH SINGH\\Favorites\\Downloads\\customer_churn (1).csv")
df.head(5)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns
df = pd.read_csv("C:\\Users\\MANISH SINGH\\Favorites\\Downloads\\customer_churn (1).csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# # replacing blanks with 0 as tenure is 0 and no recorded are totalcharges

# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns
df = pd.read_csv("C:\\Users\\MANISH SINGH\\Favorites\\Downloads\\customer_churn (1).csv")
df["TotalCharges"] = df["TotalCharges"].replace(" ","0")
df["TotalCharges"] = df["TotalCharges"].astype("float")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns
df = pd.read_csv("C:\\Users\\MANISH SINGH\\Favorites\\Downloads\\customer_churn (1).csv")
df.isnull().sum()#.sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7043.000000
# mean        0.162147    32.371149       64.761692   2279.734304
# std         0.368612    24.559481       30.090047   2266.794470
# min         0.000000     0.000000       18.250000      0.000000
# 25%         0.000000     9.000000       35.500000    398.550000
# 50%         0.000000    29.000000       70.350000   1394.550000
# 75%         0.000000    55.000000       89.850000   3786.600000
# max         1.000000    72.000000      118.750000   8684.800000

# %%
df["customerID"].duplicated().sum()
# Out:
# 0

# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns
df = pd.read_csv("C:\\Users\\MANISH SINGH\\Favorites\\Downloads\\customer_churn (1).csv")
def convert(value):
    if value == 1:
        return "yes"
    else:
        return "no"
df["SeniorCitizen"] = df["SeniorCitizen"].apply(convert)

# %% [markdown]
# # Exploratory Data Analsis

# %% [markdown]
# #it is converted 0 or 1 value of seniorcitizen to yes/no to make it easier to understand.

# %%
df.head(3)
# Out:
#    customerID  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            no     Yes         No       1           No
# 1  5575-GNVDE    Male            no      No         No      34          Yes
# 2  3668-QPYBK    Male            no      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
#
#       PaymentMethod MonthlyCharges  TotalCharges Churn
# ...

# %% [markdown]
# # Churn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("C:\\Users\\MANISH SINGH\\Favorites\\Downloads\\customer_churn (1).csv")
plt.figure(figsize = (5,4))
ankur = sns.countplot(data = df, x = "Churn" )
plt.title("Count of Customer by Churn",fontsize = 10)

for ax in ankur.containers:
    ankur.bar_label(ax)

# %%
import matplotlib.pyplot as plt

y = df["Churn"].value_counts().index   
x = df["Churn"].value_counts().values  

plt.figure(figsize = (4,4))
plt.pie(x, labels=y, startangle=60, autopct="%0.2f%%") 
plt.title("percentage of Customer Churn", fontsize=10)
plt.legend(loc=2)
plt.show()

# %% [markdown]
# #percentage of customer churn by using pie chart.

# %% [markdown]
# # Gender

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("C:\\Users\\MANISH SINGH\\Favorites\\Downloads\\customer_churn (1).csv")
plt.figure(figsize = (4,4))
ankur = sns.countplot(data = df, x = "gender",hue = "Churn")

plt.title("Churn by Gender",fontsize = 10)
for dk in ankur.containers:
    ankur.bar_label(dk)

# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns
df = pd.read_csv("C:\\Users\\MANISH SINGH\\Favorites\\Downloads\\customer_churn (1).csv")
def convert(value):
    if value == 1:
        return "yes"
    else:
        return "no"
df["SeniorCitizen"] = df["SeniorCitizen"].apply(convert)

# %%
df.head(3)
# Out:
#    customerID  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            no     Yes         No       1           No
# 1  5575-GNVDE    Male            no      No         No      34          Yes
# 2  3668-QPYBK    Male            no      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
#
#       PaymentMethod MonthlyCharges  TotalCharges Churn
# ...

# %% [markdown]
# # SeniorCitizen

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("C:\\Users\\MANISH SINGH\\Favorites\\Downloads\\customer_churn (1).csv")
plt.figure(figsize = (5,4))
ax = sns.countplot(x = "SeniorCitizen",data = df, hue = "Churn")
for dk in ax.containers:
    ax.bar_label(dk)
plt.title("Count of Customer by SeniorCitizen",fontsize = 12)
plt.show()

# %% [markdown]
# #As we can see that the most of employees are Attrition in 0 (0:No,1:Yes) in Seniorcitizen.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv("C:\\Users\\MANISH SINGH\\Favorites\\Downloads\\customer_churn (1).csv")

# Calculate counts for each category
counts = df.groupby(['SeniorCitizen', 'Churn']).size().unstack(fill_value=0)

# Calculate the percentage for each category within SeniorCitizen group
percentage = counts.div(counts.sum(axis=1), axis=0) * 100

# Plot the stacked bar chart
fig, ax = plt.subplots(figsize=(5, 5))
percentage.plot(kind='bar', stacked=True, color=["lightblue", "salmon"], ax=ax)

# Add labels and title
plt.title("Churn by SeniorCitizen (Stacked bar chart)")
plt.xlabel("Senior Citizen (1: Yes, 0: No)")
plt.ylabel("Percentage")
plt.xticks(rotation=0)

# Correctly position percentage labels on bars
for i, (index, row) in enumerate(percentage.iterrows()):
    no_churn = row[0]  # No churn percentage
    yes_churn = row[1]  # Yes churn percentage
    
    ax.text(i, no_churn / 2, f"{no_churn:.1f}%", ha='center', va='center', fontsize=10, color='black')
    ax.text(i, no_churn + yes_churn / 2, f"{yes_churn:.1f}%", ha='center', va='center', fontsize=10, color='black')

# Show legend
plt.legend(title="Churn", labels=["No", "Yes"])
plt.show()

# %% [markdown]
# #Comparative a greated pecentage of people in senior citizen category have churned

# %% [markdown]
# #Created with Chatgpt.

# %% [markdown]
# # Tenure

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("C:\\Users\\MANISH SINGH\\Favorites\\Downloads\\customer_churn (1).csv")
plt.figure(figsize =( 9,5))
sns.histplot(x = "tenure", data = df, hue = "Churn",bins = 72)
plt.title("Churn by tenure" ,fontsize =15)
plt.show()

# %% [markdown]
# #that people who have used our services for a long time have stayed and people who have used our servies
# for a 1 or 2 month have churn

# %% [markdown]
# # Contract

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("C:\\Users\\MANISH SINGH\\Favorites\\Downloads\\customer_churn (1).csv")
plt.figure(figsize = (4,4))
ankur = sns.countplot(data = df, x = "Contract",hue = "Churn")

plt.title("Count of Customer by Contract",fontsize = 10)
for dk in ankur.containers:
    ankur.bar_label(dk)

# %% [markdown]
# #that people who have month to month contract are likely to churn then from those who have 1 or 2 years of contract

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("C:\\Users\\MANISH SINGH\\Favorites\\Downloads\\customer_churn (1).csv")
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %% [markdown]
# # PaymentMethod

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("C:\\Users\\MANISH SINGH\\Favorites\\Downloads\\customer_churn (1).csv")
plt.figure(figsize = (6,4))
plt.xticks(rotation = 45)
ankur = sns.countplot(data = df, x = "PaymentMethod",hue = "Churn")

plt.title("Count of Customer by Payment Method",fontsize = 10)
for dk in ankur.containers:
    ankur.bar_label(dk)

# %% [markdown]
#  #we can see that most  customer is likely to churn when he is using a elecatronic cheak as a payment method.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("C:\\Users\\MANISH SINGH\\Favorites\\Downloads\\customer_churn (1).csv")
df.columns.values
# Out:
# array(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges',
#        'TotalCharges', 'Churn'], dtype=object)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

data = {
    'PhoneService': ['Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No'],
    'MultipleLines': ['No', 'Yes', 'No', 'Yes', 'No', 'No', 'Yes'],
    'InternetService': ['DSL', 'Fiber optic', 'DSL', 'Fiber optic', 'No', 'DSL', 'No'],
    'OnlineSecurity': ['No', 'Yes', 'No', 'No', 'Yes', 'No', 'Yes'],
    'OnlineBackup': ['Yes', 'No', 'Yes', 'No', 'Yes', 'Yes', 'No'],
    'DeviceProtection': ['No', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes'],
    'TechSupport': ['Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'No'],
    'StreamingTV': ['No', 'Yes', 'No', 'No', 'Yes', 'Yes', 'No'],
    'StreamingMovies': ['Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'No'],
    'Churn': ['Yes', 'No', 'Yes', 'No', 'No', 'Yes', 'No'],  }

df = pd.DataFrame(data)

fig, axes = plt.subplots(3, 3, figsize=(15, 12)) 
fig.suptitle("Count Plots for Different Services (Hue = Churn)", fontsize=16)

columns = df.columns[:-1]  
for ax, col in zip(axes.flatten(), columns):
    sns.countplot(x=df[col], hue=df['Churn'], ax=ax, palette="pastel")
    ax.set_title(col)
    ax.set_xlabel("")
    ax.set_ylabel("Count")
    ax.tick_params(axis='x', rotation=45)

plt.tight_layout(rect=[0, 0, 1, 0.96]) 
plt.show()

# %%
#InternetService, and OnlineSecurity have higher retention, with more customers staying. StreamingTV, StreamingMovies,and 
#DeviceProtection show more balanced churn, with a significant number of customers leaving.Churn rates vary widely depending
#on the service.
